# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
#Load test data
df = pd.read_csv('../data/test_df.csv')

# %%
df.head()

# %%
df.info()

# %%
df = df[["t_id","tour_wk","t_surf","m_num","t_rd_num","p_id","p_name","p_ret_pts_won%"]]

# %%
df2 = df.loc[df["p_name"] == "Roger Federer"]

# %%
# We are going to take a time-decaying version of % serve points won. The idea for this first part of the operation is
# that, looking back from a given match on a surface-specific basis, we will average the previous hundred matches in groups 
# of 10. We will use some trickiness to contend with the "runway problem".For the earliest 10 matches in entire player sample, we
# will allow the average of 10 to include as few as one matches. As we move beyond a player's first ten matches in the sample, we
# will allow as few as 5 matches in a group of 10 (eg, if a player has played exactly 15 matches ) on hard courts, we get a full
# previous 10 matches sample looking back from the most recent match and a five match sample for the second 10 matches looking
# back from the most recent match. But if the player has only played 14 matches, we will back step so that the second sample
# includes matches -10 to -14, instead of just matches -11 through -13. -9 to -13 instead of just -12 through -13 and so on. The trade
# off for not having thin data at the end of a sample, is slight overlap in matches counted between adjacent groups of 10. 

#We do get stuck with the very first match for a player, on a given surface, in the sample having a NaN. We may end up simply removing 
#these from the overall sample at a later step simply because we don't have requisite data for projection.

df2 = df2.iloc[::-1]

df2['p_pts_won%_1to10'] = df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(1))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1)))
df2['p_pts_won%_1to10'] = df2['p_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1)))

df2['p_pts_won%_11to20'] = df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(11))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(11)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(11)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(11)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(11)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_11to20'] = df2['p_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_pts_won%_21to30'] = df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(21))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(21)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(21)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(21)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(21)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_21to30'] = df2['p_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_pts_won%_31to40'] = df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(31))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(31)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(31)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(31)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(31)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(31)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(30)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(29)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(28)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(27)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(26)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(25)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(24)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(23)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(22)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_31to40'] = df2['p_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_pts_won%_41to50'] = df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(41))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(41)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(41)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(41)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(41)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(41)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(40)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(39)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(38)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(37)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(36)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(35)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(34)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(33)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(32)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(31)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(30)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(29)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(28)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(27)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(26)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(25)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(24)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(23)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(22)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_pts_won%_41to50'] = df2['p_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2 = df2.iloc[::-1]

# %%
# Now we will take the by-10s past pts won % data per player created above and make a decay fxn-weighted version to evaluate past 
#performance at any given match for prediction

df2["p_pts_won%_l50_decay"] = (((df2['p_pts_won%_1to10'] * 5) + (df2['p_pts_won%_11to20'] * 4) + (df2['p_pts_won%_21to30'] * 3) 
+ (df2['p_pts_won%_31to40'] * 2) + (df2['p_pts_won%_41to50'] * 1))/15).round(2)

# %%
df2.tail(30)

# %%
#df2.drop(["p_pts_won%_11to20","p_pts_won%_21to30","p_pts_won%_31to40","p_pts_won%_41to50"],axis=1, inplace=True)
df2.rename(columns={'p_pts_won%_1to10': 'p_pts_won%_l10'}, inplace=True)
df2

# %%
# performance integration over the last 50 surface-specific matches by 10s, but just for serve pts ("p_sv_pts_won%_x_to_y")
df2 = df2.iloc[::-1]

df2['p_sv_pts_won%_1to10'] = df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(1))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1)))
df2['p_sv_pts_won%_1to10'] = df2['p_sv_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1)))

df2['p_sv_pts_won%_11to20'] = df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(11))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(11)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(11)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(11)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(11)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_11to20'] = df2['p_sv_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_sv_pts_won%_21to30'] = df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(21))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(21)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(21)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(21)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(21)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_21to30'] = df2['p_sv_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_sv_pts_won%_31to40'] = df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(31))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(31)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(31)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(31)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(31)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(31)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(30)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(29)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(28)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(27)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(26)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(25)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(24)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(23)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(22)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_31to40'] = df2['p_sv_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_sv_pts_won%_41to50'] = df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(41))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(41)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(41)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(41)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(41)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(41)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(40)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(39)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(38)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(37)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(36)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(35)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(34)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(33)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(32)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(31)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(30)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(29)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(28)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(27)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(26)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(25)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(24)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(23)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(22)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_sv_pts_won%_41to50'] = df2['p_sv_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_sv_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2 = df2.iloc[::-1]

# %%
# Now we will take the by-10s past serve pts won % data per player created above and make a decay fxn-weighted version to evaluate past 
# serve performance at any given match for prediction

df2["p_sv_pts_won%_l50_decay"] = (((df2['p_sv_pts_won%_1to10'] * 5) + (df2['p_sv_pts_won%_11to20'] * 4) + (df2['p_sv_pts_won%_21to30'] * 3) 
+ (df2['p_sv_pts_won%_31to40'] * 2) + (df2['p_sv_pts_won%_41to50'] * 1))/15).round(2)

# %%
df2.drop(["p_sv_pts_won%_11to20","p_sv_pts_won%_21to30","p_sv_pts_won%_31to40","p_sv_pts_won%_41to50"],axis=1, inplace=True)
df2.rename(columns={'p_sv_pts_won%_1to10': 'p_sv_pts_won%_l10'}, inplace=True)
df2

# %%
df2.tail(30)

# %%
# performance integration over the last 50 surface-specific matches by 10s, but just for return pts ("p_ret_pts_won%_x_to_y")
df2 = df2.iloc[::-1]

df2['p_ret_pts_won%_1to10'] = df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(1))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1)))
df2['p_ret_pts_won%_1to10'] = df2['p_ret_pts_won%_1to10'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1)))

df2['p_ret_pts_won%_11to20'] = df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(11))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(11)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(11)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(11)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(11)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_11to20'] = df2['p_ret_pts_won%_11to20'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_ret_pts_won%_21to30'] = df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(21))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(21)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(21)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(21)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(21)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_21to30'] = df2['p_ret_pts_won%_21to30'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_ret_pts_won%_31to40'] = df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(31))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(31)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(31)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(31)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(31)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(31)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(30)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(29)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(28)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(27)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(26)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(25)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(24)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(23)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(22)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_31to40'] = df2['p_ret_pts_won%_31to40'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2['p_ret_pts_won%_41to50'] = df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 10).mean().round(2).shift(41))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 9).mean().round(2).shift(41)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 8).mean().round(2).shift(41)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 7).mean().round(2).shift(41)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 6).mean().round(2).shift(41)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(41)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(40)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(39)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(38)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(37)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(36)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(35)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(34)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(33)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(32)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(31)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(30)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(29)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(28)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(27)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(26)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(25)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(24)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(23)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(22)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(21)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(20)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(19)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(18)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(17)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(16)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(15)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(14)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(13)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(12)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(11))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(10)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(9)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(8)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(7)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(6)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(5)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(4)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(3)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(2)))
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 5).mean().round(2).shift(1))) #you can't go to a zero shift, because this would mean counting matches that haven't happened yet
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 4).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 3).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 2).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample
df2['p_ret_pts_won%_41to50'] = df2['p_ret_pts_won%_41to50'].fillna(df2.groupby(['p_id','t_surf'])['p_ret_pts_won%'].transform(lambda x: x.rolling(window=10, min_periods = 1).mean().round(2).shift(1))) #given the above, we will lower the period requirement stepping back down to 1 to cover the last few matches in the sample

df2 = df2.iloc[::-1]

# %%
# Now we will take the by-10s past return pts won % data per player created above and make a decay fxn-weighted version to evaluate past 
# return performance at any given match for prediction

df2["p_ret_pts_won%_l50_decay"] = (((df2['p_ret_pts_won%_1to10'] * 5) + (df2['p_ret_pts_won%_11to20'] * 4) + (df2['p_ret_pts_won%_21to30'] * 3) 
+ (df2['p_ret_pts_won%_31to40'] * 2) + (df2['p_ret_pts_won%_41to50'] * 1))/15).round(2)

# %%
df2.drop(["p_ret_pts_won%_11to20","p_ret_pts_won%_21to30","p_ret_pts_won%_31to40","p_ret_pts_won%_41to50"],axis=1, inplace=True)
df2.rename(columns={'p_ret_pts_won%_1to10': 'p_ret_pts_won%_l10'}, inplace=True)
df2

# %%
df2.tail(30)
